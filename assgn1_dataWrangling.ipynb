# %%
import pandas as pd

# %%
ls
# Out:
# anaconda3/    Downloads/          Main-Projects/     nltk_data/     snap/
# assgn1.ipynb  eclipse/            mongo_backup_3_6/  Pictures/      Templates/
# Desktop/      eclipse-workspace/  mongodb-crud-app/  Public/        Videos/
# Documents/    examples.desktop    Music/             seaborn-data/

# %%
import os
os.getcwd()
# Out:
# '/home/csl-4'

# %%
os.listdir()
# Out:
# ['Music',
#  '.gnupg',
#  '.eclipse',
#  '.config',
#  '.nvm',
#  'assgn1.ipynb',
#  '.vscode',
#  'examples.desktop',
#  'mongo_backup_3_6',
#  '.local',
#  'seaborn-data',
#  'Public',
#  '.bash_history',
#  '.ICEauthority',
#  'Videos',
#  '.mongodb',
#  '.p2',
#  '.swt',
#  '.gphoto',
#  '.pki',
#  'archive.zip',
#  '.bashrc',
#  '.viminfo',
#  'Pictures',
#  '.dotnet',
#  '.gvfs',
#  '.condarc',
#  '.cache',
#  'eclipse',
#  '.mozilla',
#  'eclipse-workspace',
#  '.thunderbird',
#  '.sudo_as_admin_successful',
#  '.conda',
#  'anaconda3',
#  '.ipynb_checkpoints',
#  '.pam_environment',
#  '.ssh',
#  'Templates',
#  'Main-Projects',
#  'Downloads',
#  'Desktop',
#  '.anaconda',
#  '.mongorc.js',
#  '.dbus',
#  '.keras',
#  '.gnome',
#  'nltk_data',
#  'Documents',
#  '.jupyter',
#  'snap',
#  '.npm',
#  'mongodb-crud-app',
#  '.python_history',
#  '.dbshell',
#  '.ipython',
#  '.continuum']

# %% [markdown]
# ### Method 1: Dataset Loaded from Kaggle (ZIP Download)
# The dataset was downloaded from Kaggle in ZIP format, extracted, and loaded using Pandas.

# %%
import pandas as pd

df_kaggle = pd.read_csv("/home/csl-4/archive.csv")
 
df_kaggle.head()
# Out:
#     id                     title original_language release_date  vote_average  \
# 0  278  The Shawshank Redemption                en   1994-09-23         8.706
# 1  238             The Godfather                en   1972-03-14         8.690
# 2  240     The Godfather Part II                en   1974-12-20         8.575
# 3  424          Schindler's List                en   1993-12-15         8.565
# 4  389              12 Angry Men                en   1957-04-10         8.546
#
#    vote_count  popularity                                           overview  \
# 0       26840     150.307  Imprisoned in the 1940s for the double murder ...
# 1       20373     122.973  Spanning the years 1945 to 1955, a chronicle o...
# 2       12291      94.204  In the continuing saga of the Corleone crime f...
# 3       15695      74.615  The true story of how businessman Oskar Schind...
# 4        8522      54.678  The defense and the prosecution have rested an...
#
# ...

# %% [markdown]
# ### Method 2: Dataset Loaded Directly Using URL
#
# In this method, a dataset was imported directly into the Jupyter Notebook from an online source using its URL and the Pandas library.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

df_url = pd.read_csv(url)
df_url.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_url.shape
df_url.columns
df_url.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Method 3: Manually Created Dataset
#
# In this method, a custom dataset was created manually using Python data structures and converted into a Pandas DataFrame.

# %%
import pandas as pd

data = {
    "Student_ID": [1, 2, 3, 4, 5],
    "Name": ["Amit", "Riya", "Suresh", "Neha", "Rahul"],
    "Marks": [78, 85, 69, 90, 72],
    "Attendance": [92, 88, 75, 95, 80]
}

df_custom = pd.DataFrame(data)
df_custom
# Out:
#    Student_ID    Name  Marks  Attendance
# 0           1    Amit     78          92
# 1           2    Riya     85          88
# 2           3  Suresh     69          75
# 3           4    Neha     90          95
# 4           5   Rahul     72          80

# %%
df_custom.shape
df_custom.describe()
# Out:
#        Student_ID      Marks  Attendance
# count    5.000000   5.000000    5.000000
# mean     3.000000  78.800000   86.000000
# std      1.581139   8.757854    8.336666
# min      1.000000  69.000000   75.000000
# 25%      2.000000  72.000000   80.000000
# 50%      3.000000  78.000000   88.000000
# 75%      4.000000  85.000000   92.000000
# max      5.000000  90.000000   95.000000

# %%
df_custom.to_csv("student_data.csv", index=False)

# %% [markdown]
# ### method 4 - using mysql

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host="localhost",
    user="dsbda_user",
    password="dsbda123",
    database="dsbda"
)

df_mysql = pd.read_sql("SELECT * FROM employees", conn)
df_mysql
# Out:
#    emp_id   name department  salary
# 0       1   Aman         IT   60000
# 1       2  Pooja         HR   45000
# 2       3   Ravi    Finance   50000
# 3       4   Neha         IT   65000

# %% [markdown]
# # data wrangling

# %%
import pandas as pd

data = pd.read_csv("/home/csl-4/7326/archive.csv")

# %%
data.head()
# Out:
#     id                     title original_language release_date  vote_average  \
# 0  278  The Shawshank Redemption                en   1994-09-23         8.706
# 1  238             The Godfather                en   1972-03-14         8.690
# 2  240     The Godfather Part II                en   1974-12-20         8.575
# 3  424          Schindler's List                en   1993-12-15         8.565
# 4  389              12 Angry Men                en   1957-04-10         8.546
#
#    vote_count  popularity                                           overview  \
# 0       26840     150.307  Imprisoned in the 1940s for the double murder ...
# 1       20373     122.973  Spanning the years 1945 to 1955, a chronicle o...
# 2       12291      94.204  In the continuing saga of the Corleone crime f...
# 3       15695      74.615  The true story of how businessman Oskar Schind...
# 4        8522      54.678  The defense and the prosecution have rested an...
#
# ...

# %%
print(data.shape)
# Out:
# (9630, 10)

# %%
data.describe()
# Out:
#                  id  vote_average    vote_count   popularity
# count  9.630000e+03   9630.000000   9630.000000  9630.000000
# mean   1.944046e+05      6.633820   1976.992004    25.522728
# std    2.576246e+05      0.783581   3124.089193    58.278888
# min    2.000000e+00      2.200000    300.000000     0.018000
# 25%    1.013825e+04      6.106000    468.000000    10.780250
# 50%    3.748350e+04      6.659000    843.000000    15.620000
# 75%    3.524915e+05      7.200000   1964.750000    25.325000
# max    1.226578e+06      8.706000  36306.000000  2811.772000

# %%
data.dtypes
# Out:
# id                     int64
# title                 object
# original_language     object
# release_date          object
# vote_average         float64
# vote_count             int64
# popularity           float64
# overview              object
# genre_ids             object
# Genres                object
# dtype: object

# %%
data["id"].dtype
# Out:
# dtype('int64')

# %%
data["title"].dtype
# Out:
# dtype('O')

# %%
data["Genres"].dtype
# Out:
# dtype('O')

# %%
data["popularity"].dtype
# Out:
# dtype('float64')

# %%
data["id"].dropna()
# Out:
# 0         278
# 1         238
# 2         240
# 3         424
# 4         389
#         ...
# 9625    12142
# 9626    13805
# 9627    11059
# 9628    14164
# 9629    40016
# Name: id, Length: 9630, dtype: int64

# %%
data["id"]=data["id"].astype("Float64")

# %%
data.dtypes
# Out:
# id                   Float64
# title                 object
# original_language     object
# release_date          object
# vote_average         float64
# vote_count             int64
# popularity           float64
# overview              object
# genre_ids             object
# Genres                object
# dtype: object

# %%
data["id"]=data["id"].astype("Int64")

# %%
data["id"].dtypes
# Out:
# Int64Dtype()

# %%
data.head(10)
# Out:
#        id                        title original_language release_date  \
# 0     278     The Shawshank Redemption                en   1994-09-23
# 1     238                The Godfather                en   1972-03-14
# 2     240        The Godfather Part II                en   1974-12-20
# 3     424             Schindler's List                en   1993-12-15
# 4     389                 12 Angry Men                en   1957-04-10
# 5     129                Spirited Away                ja   2001-07-20
# 6   19404  Dilwale Dulhania Le Jayenge                hi   1995-10-20
# 7     155              The Dark Knight                en   2008-07-16
# 8  496243                     Parasite                ko   2019-05-30
# 9     497               The Green Mile                en   1999-12-10
#
#    vote_average  vote_count  popularity  \
# 0         8.706       26840     150.307
# 1         8.690       20373     122.973
# 2         8.575       12291      94.204
# ...

# %%
import numpy as np
data = data.replace("?", np.NaN)

# %%
data.isnull().sum()
# Out:
# id                   0
# title                0
# original_language    0
# release_date         0
# vote_average         0
# vote_count           0
# popularity           0
# overview             0
# genre_ids            0
# Genres               0
# dtype: int64

# %%
data.tail(10)
# Out:
#           id                          title original_language release_date  \
# 9620  485774                 The Open House                en   2018-01-19
# 9621   10870     Lucky Luke and the Daltons                fr   2004-11-08
# 9622   70584        Hellraiser: Revelations                en   2011-10-18
# 9623   74849  The Star Wars Holiday Special                en   1978-11-17
# 9624    5491              Battlefield Earth                en   2000-05-12
# 9625   12142              Alone in the Dark                en   2005-01-28
# 9626   13805                 Disaster Movie                en   2008-08-29
# 9627   11059              House of the Dead                en   2003-04-11
# 9628   14164           Dragonball Evolution                en   2009-03-12
# 9629   40016     Birdemic: Shock and Terror                en   2010-02-27
#
#       vote_average  vote_count  popularity  \
# 9620         3.701        1338       7.923
# 9621         3.680         337       9.716
# ...

# %%
data.isnull().any().any()
# Out:
# False

# %%
csv_data = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data.csv")

# %%
csv_data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
csv_data.isnull().any().any()
# Out:
# False

# %%
print(csv_data.columns)
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
csv_data.dtypes
# Out:
# CustomerID                 int64
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
csv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
csv_data.values
# Out:
# array([[1, 'Male', 19, 15, 39],
#        [2, 'Male', 21, 15, 81],
#        [3, 'Female', 20, 16, 6],
#        [4, 'Female', 23, 16, 77],
#        [5, 'Female', 31, 17, 40],
#        [6, 'Female', 22, 17, 76],
#        [7, 'Female', 35, 18, 6],
#        [8, 'Female', 23, 18, 94],
#        [9, 'Male', 64, 19, 3],
#        [10, 'Female', 30, 19, 72],
#        [11, 'Male', 67, 19, 14],
#        [12, 'Female', 35, 19, 99],
#        [13, 'Female', 58, 20, 15],
#        [14, 'Female', 24, 20, 77],
#        [15, 'Male', 37, 20, 13],
#        [16, 'Male', 22, 20, 79],
#        [17, 'Female', 35, 21, 35],
#        [18, 'Male', 20, 21, 66],
#        [19, 'Male', 52, 23, 29],
#        [20, 'Female', 35, 23, 98],
#        [21, 'Male', 35, 24, 35],
#        [22, 'Male', 25, 24, 73],
#        [23, 'Female', 46, 25, 5],
#        [24, 'Male', 31, 25, 73],
#        [25, 'Female', 54, 28, 14],
#        [26, 'Male', 29, 28, 82],
#        [27, 'Female', 45, 28, 32],
#        [28, 'Male', 35, 28, 61],
# ...

# %%
csv_data.value_counts()
# Out:
# CustomerID  Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 1           Male    19   15                  39                        1
# 138         Male    32   73                  73                        1
# 128         Male    40   71                  95                        1
# 129         Male    59   71                  11                        1
# 130         Male    38   71                  75                        1
#                                                                       ..
# 70          Female  32   48                  47                        1
# 71          Male    70   49                  55                        1
# 72          Female  47   49                  42                        1
# 73          Female  60   50                  49                        1
# 200         Male    30   137                 83                        1
# Length: 200, dtype: int64

# %%
csv_data.ndim
# Out:
# 2

# %%
csv_data.size
# Out:
# 1000

# %%
csv_data.shape
# Out:
# (200, 5)

# %%
csv_data.empty
# Out:
# False

# %%
print(csv_data["Age"])
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
csv_data.loc[5,'CustomerID']
# Out:
# 6

# %%
csv_data.loc[5]
# Out:
# CustomerID                     6
# Genre                     Female
# Age                           22
# Annual Income (k$)            17
# Spending Score (1-100)        76
# Name: 5, dtype: object

# %%
print(csv_data.loc[2:5])
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76

# %%
print(csv_data.iloc[5])
# Out:
# CustomerID                     6
# Genre                     Female
# Age                           22
# Annual Income (k$)            17
# Spending Score (1-100)        76
# Name: 5, dtype: object

# %%
print(csv_data["Age"].iloc[1])
# Out:
# 21

# %%
print(csv_data.iloc[5:10])
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
print(csv_data[csv_data.Genre=='Female'])
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# ..          ...     ...  ...                 ...                     ...
# 191         192  Female   32                 103                      69
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
#
# [112 rows x 5 columns]

# %%
print(csv_data[(csv_data.Genre=='Female') & (csv_data.Age>60)])
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 40           41  Female   65                  38                      35
# 62           63  Female   67                  47                      52
# 67           68  Female   68                  48                      48
# 90           91  Female   68                  59                      55
# 106         107  Female   66                  63                      50
# 116         117  Female   63                  65                      43

# %%
csv_data[csv_data.Genre.str.startswith('M')]
# Out:
#      CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  Male   19                  15                      39
# 1             2  Male   21                  15                      81
# 8             9  Male   64                  19                       3
# 10           11  Male   67                  19                      14
# 14           15  Male   37                  20                      13
# ..          ...   ...  ...                 ...                     ...
# 187         188  Male   28                 101                      68
# 192         193  Male   33                 113                       8
# 197         198  Male   32                 126                      74
# 198         199  Male   32                 137                      18
# 199         200  Male   30                 137                      83
#
# [88 rows x 5 columns]

# %%
names = ['M','F','Male']
csv_data[csv_data.Genre.isin(names)]
# Out:
#      CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  Male   19                  15                      39
# 1             2  Male   21                  15                      81
# 8             9  Male   64                  19                       3
# 10           11  Male   67                  19                      14
# 14           15  Male   37                  20                      13
# ..          ...   ...  ...                 ...                     ...
# 187         188  Male   28                 101                      68
# 192         193  Male   33                 113                       8
# 197         198  Male   32                 126                      74
# 198         199  Male   32                 137                      18
# 199         200  Male   30                 137                      83
#
# [88 rows x 5 columns]

# %%
csv_data.query('Genre == "Female" and Age > 60')
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 40           41  Female   65                  38                      35
# 62           63  Female   67                  47                      52
# 67           68  Female   68                  48                      48
# 90           91  Female   68                  59                      55
# 106         107  Female   66                  63                      50
# 116         117  Female   63                  65                      43

# %%
print(csv_data.describe())
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
print(csv_data.describe(include="all"))
# Out:
#         CustomerID   Genre         Age  Annual Income (k$)  \
# count   200.000000     200  200.000000          200.000000
# unique         NaN       2         NaN                 NaN
# top            NaN  Female         NaN                 NaN
# freq           NaN     112         NaN                 NaN
# mean    100.500000     NaN   38.850000           60.560000
# std      57.879185     NaN   13.969007           26.264721
# min       1.000000     NaN   18.000000           15.000000
# 25%      50.750000     NaN   28.750000           41.500000
# 50%     100.500000     NaN   36.000000           61.500000
# 75%     150.250000     NaN   49.000000           78.000000
# max     200.000000     NaN   70.000000          137.000000
#
#         Spending Score (1-100)
# count               200.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                 50.200000
# std                  25.823522
# ...

# %%
csv_data.describe(include=[np.number])
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
print(csv_data.describe(exclude=["O"]))
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
csv_data.isnull()
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False               False                   False
# 2         False  False  False               False                   False
# 3         False  False  False               False                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
csv_data.isna()
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False               False                   False
# 2         False  False  False               False                   False
# 3         False  False  False               False                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
data_missing = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data_missingvalue.csv")

# %%
print(data_missing.isnull().values.any())
# Out:
# True

# %%
data_missing.dropna()
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                    39.0
# 3             4  Female  23.0                16.0                    77.0
# 6             7  Female  35.0                18.0                     6.0
# 7             8  Female  23.0                18.0                    94.0
# 9            10  Female  30.0                19.0                    72.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [195 rows x 5 columns]

# %%
data_missing.dropna()
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                    39.0
# 3             4  Female  23.0                16.0                    77.0
# 6             7  Female  35.0                18.0                     6.0
# 7             8  Female  23.0                18.0                    94.0
# 9            10  Female  30.0                19.0                    72.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [195 rows x 5 columns]

# %%
print(data_missing.isnull().values.any())
# Out:
# True

# %%
data_missing=data_missing.dropna()

# %%
print(data_missing.isnull().values.any())
# Out:
# False

# %%
csv_data= csv_data.drop("Genre", axis=1)
print(csv_data)
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1   19                  15                      39
# 1             2   21                  15                      81
# 2             3   20                  16                       6
# 3             4   23                  16                      77
# 4             5   31                  17                      40
# ..          ...  ...                 ...                     ...
# 195         196   35                 120                      79
# 196         197   45                 126                      28
# 197         198   32                 126                      74
# 198         199   32                 137                      18
# 199         200   30                 137                      83
#
# [200 rows x 4 columns]

# %%
csv_data.mean()
# Out:
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
csv_data.median()
# Out:
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
data_filling=data_missing.fillna(csv_data.mean())
print(data_filling.head(10))
# Out:
#     CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male  19.0                15.0                    39.0
# 3            4  Female  23.0                16.0                    77.0
# 6            7  Female  35.0                18.0                     6.0
# 7            8  Female  23.0                18.0                    94.0
# 9           10  Female  30.0                19.0                    72.0
# 10          11    Male  67.0                19.0                    14.0
# 11          12  Female  35.0                19.0                    99.0
# 12          13  Female  58.0                20.0                    15.0
# 13          14  Female  24.0                20.0                    77.0
# 14          15    Male  37.0                20.0                    13.0

# %%
data_filling=data_missing.fillna(csv_data.median())
print(data_filling.head(10))
# Out:
#     CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male  19.0                15.0                    39.0
# 3            4  Female  23.0                16.0                    77.0
# 6            7  Female  35.0                18.0                     6.0
# 7            8  Female  23.0                18.0                    94.0
# 9           10  Female  30.0                19.0                    72.0
# 10          11    Male  67.0                19.0                    14.0
# 11          12  Female  35.0                19.0                    99.0
# 12          13  Female  58.0                20.0                    15.0
# 13          14  Female  24.0                20.0                    77.0
# 14          15    Male  37.0                20.0                    13.0

# %%
csv_data['Annual Income (k$)'].astype('float')
# Out:
# 0       15.0
# 1       15.0
# 2       16.0
# 3       16.0
# 4       17.0
#        ...
# 195    120.0
# 196    126.0
# 197    126.0
# 198    137.0
# 199    137.0
# Name: Annual Income (k$), Length: 200, dtype: float64

# %%
csv_data.dtypes
# Out:
# CustomerID                int64
# Age                       int64
# Annual Income (k$)        int64
# Spending Score (1-100)    int64
# dtype: object

# %%
csv_data['Annual Income (k$)'] = csv_data['Annual Income (k$)'].astype('float')
csv_data.dtypes
# Out:
# CustomerID                  int64
# Age                         int64
# Annual Income (k$)        float64
# Spending Score (1-100)      int64
# dtype: object

# %%
data_missing_drop = data_missing.dropna()

# %%
data_missing.dtypes
# Out:
# CustomerID                  int64
# Genre                      object
# Age                       float64
# Annual Income (k$)        float64
# Spending Score (1-100)    float64
# dtype: object

# %%
data_missing.isnull().any().any()
# Out:
# False

# %%
data_missing.fillna(method="ffill", inplace=True)

# %%
data_missing.fillna(method="bfill", inplace=True)

# %%
data_missing.isnull().any().any()
# Out:
# False

# %%
data_missing.head(10)
# Out:
#     CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male  19.0                15.0                    39.0
# 3            4  Female  23.0                16.0                    77.0
# 6            7  Female  35.0                18.0                     6.0
# 7            8  Female  23.0                18.0                    94.0
# 9           10  Female  30.0                19.0                    72.0
# 10          11    Male  67.0                19.0                    14.0
# 11          12  Female  35.0                19.0                    99.0
# 12          13  Female  58.0                20.0                    15.0
# 13          14  Female  24.0                20.0                    77.0
# 14          15    Male  37.0                20.0                    13.0

# %%
data_missing.shape
# Out:
# (195, 5)
